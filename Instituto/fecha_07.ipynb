# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
import sys
sys.path.append('../fun/')
import more_functions
import functions

# %%
path ='../data/Partido_65_local.csv'
df = pd.read_csv(path)

# %%
titulo = '11/11/2024 Instituto vs San Lorenzo'
functions.puntos_por_partido(df, titulo)
functions.por_partido(df, titulo)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
import sys
sys.path.append('../fun/')
import more_functions
import functions

# %%
path ='../data/Partido_12_visitante.csv'
df = pd.read_csv(path)

# %%
titulo = '13/10/2024 San Martin vs Instituto'
functions.puntos_por_partido(df, titulo)
functions.por_partido(df, titulo)

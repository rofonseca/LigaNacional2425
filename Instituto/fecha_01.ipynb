# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
import sys
sys.path.append('../fun/')
import more_functions
import functions

# %%
path ='../data/Partido_3_local.csv'
df = pd.read_csv(path)

# %%
functions.puntos_por_partido(df, '08/10/2024 Instituto vs Ciclista Olímpico')

# %%
functions.por_partido(df, '08/10/2024 Instituto vs Ciclista Olímpico')
